# %% [markdown]
# # 1. Basic Terminology

# %% [markdown]
# - Exploratory Data Analysis (EDA) is a task of analysing data using simple tools from Statistics, Plotting Tools, Linear Algebra to understand the dataset.
#
# - Data set is a table.

# %%
# 4 independent variables / Feature / Input variable - Sepal length, Sepal width, Petal length, Petal width
# Each row is known as a data-point / observation. - Vector (n-dimensional numerical array)
# Predict class label / Class-label / output-variable / label / response label
# Vector: 2-D, 3-D, 4-D, ..., n-D
# Iris dataset is a 4-D vector
# 1-D vector - Scalar

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load iris.csv into pandas DataFrame
iris = pd.read_csv("iris.csv")

# %%
# how many data points and features?
print(iris.shape)
# Out:
# (150, 5)

# %%
# What are the column names in our dataset?
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# How many flowers for each species are present? - How many data points are there in each species?
# balanced-dataset vs imbalanced-dataset
# Iris is a balanced dataset as the number of data points for every class are similar.

iris['species'].value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %% [markdown]
# # 2. 2-D Scatter plot

# %%
# 2-D scatter plot
# ALWAYS understand the axis: labels and scale.

iris.plot(kind ='scatter', x='sepal_length', y='sepal_width')
plt.show()

# %%
# 2-D scatter plot with color-coding for each flower type/class.
# Here, 'sns' corresponds to seaborn.

sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", size=4) \
    .map(plt.scatter, "sepal_length", "sepal_width") \
    .add_legend();
    
plt.show();

# %% [markdown]
# <h3>Observations: </h3>
#    - Using sepal_length and sepal_width features, we can distinguish Setosa flowers from others.  --- Linearly separable
#    - Separating Versicolor and Virginica is much harder as they have considerable overlap.
